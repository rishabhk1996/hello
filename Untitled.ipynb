# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
data
# Out:
#   group  ounces
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 1     a     3.0
# 0     a     4.0
# 2     a    12.0

# %%
data.sort_values(by=['group','ounces'], ascending=[True, False], inplace=True)
data
# Out:
#   group  ounces
# 2     a    12.0
# 0     a     4.0
# 1     a     3.0
# 5     b     8.0
# 4     b     7.5
# 3     b     6.0
# 8     c     6.0
# 7     c     5.0
# 6     c     3.0

# %%
import pandas as pd
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

def meat2animal(series):
    if series["food"]=='bacon':
        return 'pig'
    elif series["food"]=='pulled pork':
        return 'pig'
    elif series["food"]=='pastrami':
        return 'cow'
    elif series["food"]=='corned beef':
        return 'cow'
    elif series["food"]=='honey ham':
        return 'pig'
    else:
        return 'salmon'

# %%
data['animal'] = data['food'].map(str.upper).map(meat_to_animal)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-c0a7cff6ee3d> in <module>()
# ----> 1 data['animal'] = data['food'].map(str.upper).map(meat_to_animal)
#       2 data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
data.drop('animal', axis='columns', inplace=False)  # dropping/removing a column
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
bins = [18, 25, 35, 60, 100]

# %%
cats = pd.cut(ages,bins)
cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, object): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
data.add('animal', axis='index', inplace=True)  # dropping/removing a column
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d6505feb7332> in <module>()
# ----> 1 data.add('animal', axis='index', inplace=True)  # dropping/removing a column
#       2 data
#
# TypeError: f() got an unexpected keyword argument 'inplace'

# %%
import pandas as pd
data = pd.DataFrame({'food':['teja','g','ghd'], 'shoes':['adi','poma','spaks']})
data
te = {
    'teja': 'bhuka',
    'g': 'pyasa',
    'ghd':'hagra'
}
def tejas(series):
    if series["food"]=='teja':
    return 'adi'
    elif  series["food"]=='pyasa':
    return 'poma'
    elif series["food"]=='hagra':
    return 'spaks'
    else:
    return 'h'
# Out:
#   File "<ipython-input-25-d2aaf5b13e92>", line 11
#     return 'adi'
#          ^
# IndentationError: expected an indented block

# %%
import pandas as pd
data = pd.DataFrame(np.arange(16).reshape((4, 4)),index=['Ohio', 'Colorado', 'New York','bc'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11
# bc         12   13     14    15

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a'] * 3 + ['b'] * 4, 'ounces': [1,5,4,2,7,3,5]})
data
# Out:
#   group  ounces
# 0     a       1
# 1     a       5
# 2     a       4
# 3     b       2
# 4     b       7
# 5     b       3
# 6     b       5

# %%
import pandas as pd
data = pd.DataFrame({'name':['t', 'r'],
                    'no':[4,5]})
data
# Out:
#   name  no
# 0    t   4
# 1    r   5

# %% [raw]
# data.describe()

# %%
data.describe()
# Out:
#              no
# count  2.000000
# mean   4.500000
# std    0.707107
# min    4.000000
# 25%    4.250000
# 50%    4.500000
# 75%    4.750000
# max    5.000000

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'data1' : np.random.randn(7),
                   'data2' : np.random.randn(7)})

df.assign(ratio = df['data1'] / df['data2'])
# Out:
#       data1     data2      ratio
# 0  0.785770 -1.286727  -0.610673
# 1 -0.987229 -1.366545   0.722427
# 2 -0.298227 -0.998581   0.298651
# 3  0.547640  0.578544   0.946583
# 4  0.280216  0.620790   0.451387
# 5 -0.552932  0.392840  -1.407525
# 6 -1.342277  0.020717 -64.789654

# %%
data.drop('ratio', axis='columns', inplace=True)  # dropping/removing a column
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9416d13ca12a> in <module>()
# ----> 1 data.drop('ratio', axis='columns', inplace=True)  # dropping/removing a column
#       2 data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-e3986bf5121c> in <module>()
# ----> 1 data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
#       2 data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3137             keys = []
#    3138             for x in by:
# -> 3139                 k = self[x].values
#    3140                 if k.ndim == 2:
#    3141                     raise ValueError('Cannot sort by duplicate column %s' %
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.18.1

# %%
pd.read_json?

# %%
df = pd.read_json("http://localhost:8888/edit/Desktop/python_data_science/users.dat")

df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-a626b2a92baf> in <module>()
# ----> 1 df = pd.read_json("http://localhost:8888/edit/Desktop/python_data_science/users.dat")
#       2
#       3 df.head(5)
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\io\json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\io\json.pyc in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
# ...

# %%
import movies as ms
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-69-7b9e93cbfd5d> in <module>()
# ----> 1 import movies as ms
#
# ImportError: No module named movies

# %%
data = pd.read_csv('output_list.txt', sep=" ", header = None)
data.columns = ["a", "b", "c", "etc."]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-70-038e2bb86fd9> in <module>()
# ----> 1 data = pd.read_csv('output_list.txt', sep=" ", header = None)
#       2 data.columns = ["a", "b", "c", "etc."]
#
# ...

# %%
data = pd.read_csv('users1.txt', sep=" ", header = None)
data.columns = ["a", "b", "c", "d"]
print data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-cdbca0b5a7cd> in <module>()
#       1 data = pd.read_csv('users1.txt', sep=" ", header = None)
# ----> 2 data.columns = ["a", "b", "c", "d"]
#       3 print data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __setattr__(self, name, value)
#    2683         try:
#    2684             object.__getattribute__(self, name)
# -> 2685             return object.__setattr__(self, name, value)
#    2686         except AttributeError:
#    2687             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:44748)()
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _set_axis(self, axis, labels)
#     426
#     427     def _set_axis(self, axis, labels):
# --> 428         self._data.set_axis(axis, labels)
# ...

# %%
import pandas as pd    

with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
    df = pd.DataFrame(l.rstrip().split() for l in f)

print(df)
# Out:
#                            0
# 0         1::F::1::10::48067
# 1        2::M::56::16::70072
# 2        3::M::25::15::55117
# 3         4::M::45::7::02460
# 4        5::M::25::20::55455
# 5         6::F::50::9::55117
# 6         7::M::35::1::06810
# 7        8::M::25::12::11413
# 8        9::M::25::17::61614
# 9        10::F::35::1::95370
# 10       11::F::25::1::04093
# 11      12::M::25::12::32793
# 12       13::M::45::1::93304
# 13       14::M::35::0::60126
# 14       15::M::25::7::22903
# 15       16::F::35::0::20670
# 16       17::M::50::1::95350
# 17       18::F::18::3::95825
# 18       19::M::1::10::48073
# 19      20::M::25::14::55113
# 20      21::M::18::16::99353
# 21      22::M::18::15::53706
# 22       23::M::35::0::90049
# 23       24::F::25::7::10023
# 24       25::M::18::4::01609
# 25       26::M::25::7::23112
# 26      27::M::25::11::19130
# 27       28::F::25::1::14607
# 28       29::M::35::7::33407
# 29       30::F::35::7::19143
# ...                      ...
# ...

# %%
import pandas as pd
data = pd.DataFrame({with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
    df = pd.DataFrame(l.rstrip().split() for l in f)

})
data
# Out:
#   File "<ipython-input-77-eaabe7a3e103>", line 2
#     data = pd.DataFrame({with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
#                             ^
# SyntaxError: invalid syntax

# %%
data.sort_values(by='F')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-d2eed19be16e> in <module>()
# ----> 1 data.sort_values(by='F')
#       2 data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3149
#    3150             by = by[0]
# -> 3151             k = self[by].values
#    3152             if k.ndim == 2:
#    3153
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# ...

# %%
import pandas as pd    

with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
    df = pd.DataFrame(l.rstr().split() for l in f)

print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-106fced06b56> in <module>()
#       4
#       5 with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
# ----> 6     df = pd.DataFrame(l.rstr().split() for l in f)
#       7
#       8 print(df)
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
# --> 258                 data = list(data)
#     259             if len(data) > 0:
#     260                 if is_list_like(data[0]) and getattr(data[0], 'ndim', 1) == 1:
#
# <ipython-input-83-106fced06b56> in <genexpr>((l,))
#       4
#       5 with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
# ...

# %%
data.sort_values(by=['data1'],  inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-3165c87f2d3d> in <module>()
# ----> 1 data.sort_values(by=['data1'],  inplace=True)
#       2 data
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3149
#    3150             by = by[0]
# -> 3151             k = self[by].values
#    3152             if k.ndim == 2:
#    3153
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
# ...

# %%
import pandas as pd    

with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
    df = pd.DataFrame(l.rstrip().sep() for l in f)

print(df)
# Out:
#                            0
# 0         1::F::1::10::48067
# 1        2::M::56::16::70072
# 2        3::M::25::15::55117
# 3         4::M::45::7::02460
# 4        5::M::25::20::55455
# 5         6::F::50::9::55117
# 6         7::M::35::1::06810
# 7        8::M::25::12::11413
# 8        9::M::25::17::61614
# 9        10::F::35::1::95370
# 10       11::F::25::1::04093
# 11      12::M::25::12::32793
# 12       13::M::45::1::93304
# 13       14::M::35::0::60126
# 14       15::M::25::7::22903
# 15       16::F::35::0::20670
# 16       17::M::50::1::95350
# 17       18::F::18::3::95825
# 18       19::M::1::10::48073
# 19      20::M::25::14::55113
# 20      21::M::18::16::99353
# 21      22::M::18::15::53706
# 22       23::M::35::0::90049
# 23       24::F::25::7::10023
# 24       25::M::18::4::01609
# 25       26::M::25::7::23112
# 26      27::M::25::11::19130
# 27       28::F::25::1::14607
# 28       29::M::35::7::33407
# 29       30::F::35::7::19143
# ...                      ...
# ...

# %%
import pandas as pd    

with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
    df = pd.DataFrame(l.rstrip().split() for l in f)
    df.split(",")
print(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-c5051ef26b1b> in <module>()
#       3 with open('C:/Users/katariya/Desktop/python_data_science/users.dat','r') as f:
#       4     df = pd.DataFrame(l.rstrip().split() for l in f)
# ----> 5     df.split("")
#       6 print(p)
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
 pd.read_csv('users1.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-94-0aff1b3ba87d> in <module>()
# ----> 1 pd.read_csv('users1.csv')
#
# C:\Users\katariya\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
 pd.read_csv('use.csv')
# Out:
#          ﻿1::F::1::10::48067
# 0        2::M::56::16::70072
# 1        3::M::25::15::55117
# 2         4::M::45::7::02460
# 3        5::M::25::20::55455
# 4         6::F::50::9::55117
# 5         7::M::35::1::06810
# 6        8::M::25::12::11413
# 7        9::M::25::17::61614
# 8        10::F::35::1::95370
# 9        11::F::25::1::04093
# 10      12::M::25::12::32793
# 11       13::M::45::1::93304
# 12       14::M::35::0::60126
# 13       15::M::25::7::22903
# 14       16::F::35::0::20670
# 15       17::M::50::1::95350
# 16       18::F::18::3::95825
# 17       19::M::1::10::48073
# 18      20::M::25::14::55113
# 19      21::M::18::16::99353
# 20      22::M::18::15::53706
# 21       23::M::35::0::90049
# 22       24::F::25::7::10023
# 23       25::M::18::4::01609
# 24       26::M::25::7::23112
# 25      27::M::25::11::19130
# 26       28::F::25::1::14607
# 27       29::M::35::7::33407
# 28       30::F::35::7::19143
# 29       31::M::56::7::06840
# ...                      ...
# ...

# %%
 pd.read_csv(StringIO(data), names=['series', 'bar', 'baz'], header=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-c7dc4c8b4d07> in <module>()
# ----> 1 pd.read_csv(StringIO(data), names=['series', 'bar', 'baz'], header=0)
#
# NameError: name 'StringIO' is not defined

# %%
# Out:
# C:\Users\katariya\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# C:\Users\katariya\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
datam=pd.read_table('movies.dat',sep='::',names=['movies-id','title','gernes'])
datam
# Out:
# C:\Users\katariya\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#       movies-id                                              title  \
# 0             1                                   Toy Story (1995)
# 1             2                                     Jumanji (1995)
# 2             3                            Grumpier Old Men (1995)
# 3             4                           Waiting to Exhale (1995)
# 4             5                 Father of the Bride Part II (1995)
# 5             6                                        Heat (1995)
# 6             7                                     Sabrina (1995)
# 7             8                                Tom and Huck (1995)
# ...

# %%
datam=pd.read_table(users.dat',sep='::',names=['movies-id','title','gernes'])
datam
